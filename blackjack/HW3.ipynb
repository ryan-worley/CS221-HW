# %%
class SOME_MDP(object):
    moveCost = -5
    win = 20
    superWin = 100

    def __init__(self, max_State, min_State, iterations):
        self.max_State = max_State
        self.min_State = min_State
        self.iterations = iterations
        
    def startState(self):
        return 0

    def isEnd(self, state):
        if self.max_State == state:
            return True
        if self.min_State == state:
            return True
        else:
            return False

    def actions(self, state):
        results = ['add','subtract']
        return results

    def succProbReward(self, state, action):
        # Return a list of (newState, prob, reward) triples, where:
        # - newState: s' (where I might end up)
        # - prob: T(s, a, s')
        # - reward: Reward(s, a, s')
        results = []
        if action == 'add':
            if state == 1:
                results.append((state + 1, .7, self.moveCost+self.superWin))
            else:
                results.append((state - 1, .3, self.moveCost))
                results.append((state + 1, .7, self.moveCost))
        
        elif action == 'subtract':
            if state == -1:
                results.append((state - 1, .8, self.moveCost))
            else:    
                results.append((2 * state, .2, self.moveCost))
                results.append((state - 1, .8, self.moveCost+self.win))
        return results

    
    def discount(self):
        return 1.0

    def states(self):
        return [-2, -1, 0, 1, 2]
    

############################################################
# Inference algorithms

def valueIteration(mdp):
    V = {}  # state -> estimate of V_opt(state)
    pi = {}  # state -> estimate of pi_opt(state)

    # Based on current estimate of V
    def Q(state, action):
        return sum(
            prob * (reward + mdp.discount() * V[newState])
            for newState, prob, reward in mdp.succProbReward(state, action)
        )

    # Initialize
    for state in mdp.states():
        V[state] = 0

    for i in range(mdp.iterations):
        newV = {}  # new values at iteration t based on t - 1 (V)
        print('\nIteration {}:\n'.format(i))
        # Compute new values
        for state in mdp.states():
            if mdp.isEnd(state):
                newV[state], pi[state] = 0, None
            else:
                newV[state], pi[state] = max((Q(state, action), action) for action in mdp.actions(state))
            print('{}: V: {},  policy : {}'.format(state, newV[state], pi[state]))
        #raw_input()

        # Test for convergence
        if max(abs(V[state] - newV[state]) for state in mdp.states()) < 1e-10:
            break

        V = newV
        
############################################################
# Main

mdp = SOME_MDP(2,-2,2000)
#print mdp.actions(10)
#print mdp.succProbReward(3, 'tram')
valueIteration(mdp)
# Out:
# Iteration 1:
#
# -2: V: 0,  policy : None
# -1: V: -4.0,  policy : subtract
# 0: V: 11.0,  policy : subtract
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 2:
#
# -2: V: 0,  policy : None
# -1: V: 2.6999999999999993,  policy : add
# 0: V: 40.349999999999994,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 3:
#
# -2: V: 0,  policy : None
# -1: V: 23.244999999999994,  policy : add
# 0: V: 42.36,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 4:
#
# -2: V: 0,  policy : None
# -1: V: 24.651999999999997,  policy : add
# 0: V: 48.5235,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 5:
#
# -2: V: 0,  policy : None
# -1: V: 28.96645,  policy : add
# 0: V: 48.9456,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 6:
#
# -2: V: 0,  policy : None
# -1: V: 29.261919999999996,  policy : add
# 0: V: 50.239934999999996,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 7:
#
# -2: V: 0,  policy : None
# -1: V: 30.167954499999993,  policy : add
# 0: V: 50.328576,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 8:
#
# -2: V: 0,  policy : None
# -1: V: 30.230003199999995,  policy : add
# 0: V: 50.600386349999994,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 9:
#
# -2: V: 0,  policy : None
# -1: V: 30.420270444999993,  policy : add
# 0: V: 50.619000959999994,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 10:
#
# -2: V: 0,  policy : None
# -1: V: 30.433300671999994,  policy : add
# 0: V: 50.67608113349999,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 11:
#
# -2: V: 0,  policy : None
# -1: V: 30.47325679344999,  policy : add
# 0: V: 50.67999020159999,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 12:
#
# -2: V: 0,  policy : None
# -1: V: 30.475993141119993,  policy : add
# 0: V: 50.69197703803499,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 13:
#
# -2: V: 0,  policy : None
# -1: V: 30.484383926624492,  policy : add
# 0: V: 50.69279794233599,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 14:
#
# -2: V: 0,  policy : None
# -1: V: 30.484958559635192,  policy : add
# 0: V: 50.69531517798735,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 15:
#
# -2: V: 0,  policy : None
# -1: V: 30.48672062459114,  policy : add
# 0: V: 50.69548756789055,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 16:
#
# -2: V: 0,  policy : None
# -1: V: 30.486841297523384,  policy : add
# 0: V: 50.69601618737734,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 17:
#
# -2: V: 0,  policy : None
# -1: V: 30.487211331164136,  policy : add
# 0: V: 50.69605238925701,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 18:
#
# -2: V: 0,  policy : None
# -1: V: 30.487236672479906,  policy : add
# 0: V: 50.69616339934924,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 19:
#
# -2: V: 0,  policy : None
# -1: V: 30.487314379544465,  policy : add
# 0: V: 50.69617100174397,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 20:
#
# -2: V: 0,  policy : None
# -1: V: 30.487319701220777,  policy : add
# 0: V: 50.69619431386334,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 21:
#
# -2: V: 0,  policy : None
# -1: V: 30.487336019704333,  policy : add
# 0: V: 50.69619591036623,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 22:
#
# -2: V: 0,  policy : None
# -1: V: 30.487337137256358,  policy : add
# 0: V: 50.696200805911296,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 23:
#
# -2: V: 0,  policy : None
# -1: V: 30.487340564137906,  policy : add
# 0: V: 50.69620114117691,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 24:
#
# -2: V: 0,  policy : None
# -1: V: 30.487340798823833,  policy : add
# 0: V: 50.69620216924137,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 25:
#
# -2: V: 0,  policy : None
# -1: V: 30.487341518468956,  policy : add
# 0: V: 50.69620223964715,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 26:
#
# -2: V: 0,  policy : None
# -1: V: 30.487341567753003,  policy : add
# 0: V: 50.696202455540686,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 27:
#
# -2: V: 0,  policy : None
# -1: V: 30.48734171887848,  policy : add
# 0: V: 50.6962024703259,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 28:
#
# -2: V: 0,  policy : None
# -1: V: 30.487341729228127,  policy : add
# 0: V: 50.69620251566354,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 29:
#
# -2: V: 0,  policy : None
# -1: V: 30.48734176096448,  policy : add
# 0: V: 50.69620251876844,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 30:
#
# -2: V: 0,  policy : None
# -1: V: 30.487341763137906,  policy : add
# 0: V: 50.69620252828934,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 31:
#
# -2: V: 0,  policy : None
# -1: V: 30.487341769802537,  policy : add
# 0: V: 50.69620252894137,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 32:
#
# -2: V: 0,  policy : None
# -1: V: 30.487341770258958,  policy : add
# 0: V: 50.69620253094076,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 33:
#
# -2: V: 0,  policy : None
# -1: V: 30.487341771658528,  policy : add
# 0: V: 50.69620253107769,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 34:
#
# -2: V: 0,  policy : None
# -1: V: 30.48734177175438,  policy : add
# 0: V: 50.696202531497555,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 35:
#
# -2: V: 0,  policy : None
# -1: V: 30.487341772048286,  policy : add
# 0: V: 50.69620253152631,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
#
# Iteration 36:
#
# -2: V: 0,  policy : None
# -1: V: 30.487341772068415,  policy : add
# 0: V: 50.69620253161448,  policy : add
# 1: V: 66.5,  policy : add
# 2: V: 0,  policy : None
